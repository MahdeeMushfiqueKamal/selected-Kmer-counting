# %%
import pandas as pd
df = pd.read_csv('report.csv')
df.head()
# Out:
#                      kmer  line_no  isFragmented                        header
# 0  GATGATTCCATTTGATTCCATT     2516         False  >R1258|16324769_16324868|0/1
# 1  AATGGAATCAAATGGAATCATC     7156         False  >R3578|16327041_16327140|1/1
# 2  GATGATTCCATTTGATTCCATT     8594         False  >R4297|16305611_16305710|0/1
# 3  AATGGAATCAAATGGAATCATC     9402         False  >R4701|16378197_16378296|0/1
# 4  AATGGAATCAAATGGAATCATC    11756         False  >R5878|16367458_16367557|0/1

# %%
df.loc[ (df["kmer"] == "GATGATTCCATTTGATTCCATT") & (df["isFragmented"] == False)]
# Out:
#                        kmer  line_no  isFragmented  \
# 0    GATGATTCCATTTGATTCCATT     2516         False
# 2    GATGATTCCATTTGATTCCATT     8594         False
# 12   GATGATTCCATTTGATTCCATT    32658         False
# 13   GATGATTCCATTTGATTCCATT    33794         False
# 14   GATGATTCCATTTGATTCCATT    35462         False
# ..                      ...      ...           ...
# 320  GATGATTCCATTTGATTCCATT   825474         False
# 321  GATGATTCCATTTGATTCCATT   826014         False
# 322  GATGATTCCATTTGATTCCATT   826692         False
# 323  GATGATTCCATTTGATTCCATT   831336         False
# 324  GATGATTCCATTTGATTCCATT   834246         False
#
#                              header
# 0      >R1258|16324769_16324868|0/1
# 2      >R4297|16305611_16305710|0/1
# 12    >R16329|16374114_16374213|1/1
# 13    >R16897|16331161_16331260|0/1
# 14    >R17731|16328120_16328219|0/1
# ..                              ...
# 320  >R204036|16330531_16330630|0/2
# 321  >R204306|16363386_16363485|1/2
# ...

# %%
df.loc[ (df["kmer"] == "GATGATTCCATTTGATTCCATT") & (df["isFragmented"] == True)]
# Out:
#                        kmer  line_no  isFragmented  \
# 165  GATGATTCCATTTGATTCCATT   426302          True
# 175  GATGATTCCATTTGATTCCATT   453596          True
# 183  GATGATTCCATTTGATTCCATT   462090          True
# 252  GATGATTCCATTTGATTCCATT   626000          True
#
#                              header
# 165    >R4450|14289490_14289589|1/2
# 175   >R18097|16472054_16472153|1/2
# 183   >R22344|18198450_18198549|0/2
# 252  >R104299|18836800_18836899|0/2

# %%
df.loc[ (df["kmer"] == "AATGGAATCAAATGGAATCATC") & (df["isFragmented"] == False)]
# Out:
#                        kmer  line_no  isFragmented  \
# 1    AATGGAATCAAATGGAATCATC     7156         False
# 3    AATGGAATCAAATGGAATCATC     9402         False
# 4    AATGGAATCAAATGGAATCATC    11756         False
# 5    AATGGAATCAAATGGAATCATC    15906         False
# 6    AATGGAATCAAATGGAATCATC    17602         False
# ..                      ...      ...           ...
# 313  AATGGAATCAAATGGAATCATC   807146         False
# 314  AATGGAATCAAATGGAATCATC   807476         False
# 315  AATGGAATCAAATGGAATCATC   812598         False
# 316  AATGGAATCAAATGGAATCATC   812598         False
# 318  AATGGAATCAAATGGAATCATC   817420         False
#
#                              header
# 1      >R3578|16327041_16327140|1/1
# 3      >R4701|16378197_16378296|0/1
# 4      >R5878|16367458_16367557|0/1
# 5      >R7953|16368753_16368852|0/1
# 6      >R8801|16337418_16337517|1/1
# ..                              ...
# 313  >R194872|16379759_16379858|0/2
# 314  >R195037|16370593_16370692|0/2
# ...

# %%
df.loc[ (df["kmer"] == "AATGGAATCAAATGGAATCATC") & (df["isFragmented"] == True)]
# Out:
#                        kmer  line_no  isFragmented  \
# 37   AATGGAATCAAATGGAATCATC    80080          True
# 59   AATGGAATCAAATGGAATCATC   168456          True
# 278  AATGGAATCAAATGGAATCATC   707488          True
#
#                              header
# 37    >R40040|15562268_15562367|1/1
# 59    >R84228|13268034_13268133|1/1
# 278  >R145043|19242904_19243003|0/2
